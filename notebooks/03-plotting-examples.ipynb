# %% [markdown]
# # Some plotting examples
#
# https://seaborn.pydata.org/examples/index.html

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
from importlib import reload
reload(mpl)
reload(plt)
reload(sns)
# Out:
# <module 'seaborn' from '/Users/bartev/.venvs/sim/lib/python3.7/site-packages/seaborn/__init__.py'>

# %%
sns.get_data_home()
# Out:
# '/Users/bartev/seaborn-data'

# %%
fmri = sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region  signal
# 0        s13         18  stim  parietal  -0.018
# 1         s5         14  stim  parietal  -0.081
# 2        s12         18  stim  parietal  -0.081
# 3        s11         18  stim  parietal  -0.046
# 4        s10         18  stim  parietal  -0.038
# ...      ...        ...   ...       ...     ...
# 1059      s0          8   cue   frontal   0.018
# 1060     s13          7   cue   frontal  -0.029
# 1061     s12          7   cue   frontal  -0.005
# 1062     s11          7   cue   frontal  -0.025
# 1063      s0          0   cue  parietal  -0.007

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x="timepoint", y="signal",
                 hue="region", style="event",
                 data=fmri)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# # Faceted logistic regression

# %%
sns.set_theme(style='darkgrid')

df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex    age  sibsp  parch   fare embarked  class    who  adult_male deck  embark_town alive  alone
# 0         0       3    male 22.000      1      0  7.250        S  Third    man        True  NaN  Southampton    no  False
# 1         1       1  female 38.000      1      0 71.283        C  First  woman       False    C    Cherbourg   yes  False
# 2         1       3  female 26.000      0      0  7.925        S  Third  woman       False  NaN  Southampton   yes   True
# 3         1       1  female 35.000      1      0 53.100        S  First  woman       False    C  Southampton   yes  False
# 4         0       3    male 35.000      0      0  8.050        S  Third    man        True  NaN  Southampton    no   True

# %%
# Make a custom palette with gendered colors
pal = dict(male="#6495ED", female="#F08080")

# %%
# Show the survival probability as a function of age and sex
g = sns.lmplot(x="age", y="survived", col="sex", hue="sex", data=df,
               palette=pal, y_jitter=.02, logistic=True, truncate=False)

g.set(xlim=(0, 80), ylim=(-.05, 1.05))

# %% [markdown]
# # Tutorial from beginning

# %% [markdown]
# https://seaborn.pydata.org/tutorial/function_overview.html

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex
# 0       Adelie  Torgersen          39.100         18.700            181.000    3,750.000    Male
# 1       Adelie  Torgersen          39.500         17.400            186.000    3,800.000  Female
# 2       Adelie  Torgersen          40.300         18.000            195.000    3,250.000  Female
# 3       Adelie  Torgersen             nan            nan                nan          nan     NaN
# 4       Adelie  Torgersen          36.700         19.300            193.000    3,450.000  Female
# 5       Adelie  Torgersen          39.300         20.600            190.000    3,650.000    Male
# 6       Adelie  Torgersen          38.900         17.800            181.000    3,625.000  Female
# 7       Adelie  Torgersen          39.200         19.600            195.000    4,675.000    Male
# 8       Adelie  Torgersen          34.100         18.100            193.000    3,475.000     NaN
# 9       Adelie  Torgersen          42.000         20.200            190.000    4,250.000     NaN
# 10      Adelie  Torgersen          37.800         17.100            186.000    3,300.000     NaN
# 11      Adelie  Torgersen          37.800         17.300            180.000    3,700.000     NaN
# 12      Adelie  Torgersen          41.100         17.600            182.000    3,200.000  Female
# 13      Adelie  Torgersen          38.600         21.200            191.000    3,800.000    Male
# 14      Adelie  Torgersen          34.600         21.100            198.000    4,400.000    Male
# 15      Adelie  Torgersen          36.600         17.800            185.000    3,700.000  Female
# 16      Adelie  Torgersen          38.700         19.000            195.000    3,450.000  Female
# 17      Adelie  Torgersen          42.500         20.700            197.000    4,500.000    Male
# 18      Adelie  Torgersen          34.400         18.400            184.000    3,325.000  Female
# 19      Adelie  Torgersen          46.000         21.500            194.000    4,200.000    Male
# 20      Adelie     Biscoe          37.800         18.300            174.000    3,400.000  Female
# 21      Adelie     Biscoe          37.700         18.700            180.000    3,600.000    Male
# 22      Adelie     Biscoe          35.900         19.200            189.000    3,800.000  Female
# 23      Adelie     Biscoe          38.200         18.100            185.000    3,950.000    Male
# 24      Adelie     Biscoe          38.800         17.200            180.000    3,800.000    Male
# 25      Adelie     Biscoe          35.300         18.900            187.000    3,800.000  Female
# 26      Adelie     Biscoe          40.600         18.600            183.000    3,550.000    Male
# 27      Adelie     Biscoe          40.500         17.900            187.000    3,200.000  Female
# 28      Adelie     Biscoe          37.900         18.600            172.000    3,150.000  Female
# 29      Adelie     Biscoe          40.500         18.900            180.000    3,950.000    Male
# 30      Adelie      Dream          39.500         16.700            178.000    3,250.000  Female
# 31      Adelie      Dream          37.200         18.100            178.000    3,900.000    Male
# 32      Adelie      Dream          39.500         17.800            188.000    3,300.000  Female
# 33      Adelie      Dream          40.900         18.900            184.000    3,900.000    Male
# 34      Adelie      Dream          36.400         17.000            195.000    3,325.000  Female
# 35      Adelie      Dream          39.200         21.100            196.000    4,150.000    Male
# 36      Adelie      Dream          38.800         20.000            190.000    3,950.000    Male
# 37      Adelie      Dream          42.200         18.500            180.000    3,550.000  Female
# 38      Adelie      Dream          37.600         19.300            181.000    3,300.000  Female
# 39      Adelie      Dream          39.800         19.100            184.000    4,650.000    Male
# 40      Adelie      Dream          36.500         18.000            182.000    3,150.000  Female
# 41      Adelie      Dream          40.800         18.400            195.000    3,900.000    Male
# 42      Adelie      Dream          36.000         18.500            186.000    3,100.000  Female
# 43      Adelie      Dream          44.100         19.700            196.000    4,400.000    Male
# 44      Adelie      Dream          37.000         16.900            185.000    3,000.000  Female
# 45      Adelie      Dream          39.600         18.800            190.000    4,600.000    Male
# 46      Adelie      Dream          41.100         19.000            182.000    3,425.000    Male
# 47      Adelie      Dream          37.500         18.900            179.000    2,975.000     NaN
# 48      Adelie      Dream          36.000         17.900            190.000    3,450.000  Female
# 49      Adelie      Dream          42.300         21.200            191.000    4,150.000    Male
# 50      Adelie     Biscoe          39.600         17.700            186.000    3,500.000  Female
# 51      Adelie     Biscoe          40.100         18.900            188.000    4,300.000    Male
# 52      Adelie     Biscoe          35.000         17.900            190.000    3,450.000  Female
# 53      Adelie     Biscoe          42.000         19.500            200.000    4,050.000    Male
# 54      Adelie     Biscoe          34.500         18.100            187.000    2,900.000  Female
# 55      Adelie     Biscoe          41.400         18.600            191.000    3,700.000    Male
# 56      Adelie     Biscoe          39.000         17.500            186.000    3,550.000  Female
# 57      Adelie     Biscoe          40.600         18.800            193.000    3,800.000    Male
# 58      Adelie     Biscoe          36.500         16.600            181.000    2,850.000  Female
# 59      Adelie     Biscoe          37.600         19.100            194.000    3,750.000    Male
# 60      Adelie     Biscoe          35.700         16.900            185.000    3,150.000  Female
# 61      Adelie     Biscoe          41.300         21.100            195.000    4,400.000    Male
# 62      Adelie     Biscoe          37.600         17.000            185.000    3,600.000  Female
# 63      Adelie     Biscoe          41.100         18.200            192.000    4,050.000    Male
# 64      Adelie     Biscoe          36.400         17.100            184.000    2,850.000  Female
# 65      Adelie     Biscoe          41.600         18.000            192.000    3,950.000    Male
# 66      Adelie     Biscoe          35.500         16.200            195.000    3,350.000  Female
# 67      Adelie     Biscoe          41.100         19.100            188.000    4,100.000    Male
# 68      Adelie  Torgersen          35.900         16.600            190.000    3,050.000  Female
# 69      Adelie  Torgersen          41.800         19.400            198.000    4,450.000    Male
# 70      Adelie  Torgersen          33.500         19.000            190.000    3,600.000  Female
# 71      Adelie  Torgersen          39.700         18.400            190.000    3,900.000    Male
# 72      Adelie  Torgersen          39.600         17.200            196.000    3,550.000  Female
# 73      Adelie  Torgersen          45.800         18.900            197.000    4,150.000    Male
# 74      Adelie  Torgersen          35.500         17.500            190.000    3,700.000  Female
# 75      Adelie  Torgersen          42.800         18.500            195.000    4,250.000    Male
# 76      Adelie  Torgersen          40.900         16.800            191.000    3,700.000  Female
# 77      Adelie  Torgersen          37.200         19.400            184.000    3,900.000    Male
# 78      Adelie  Torgersen          36.200         16.100            187.000    3,550.000  Female
# 79      Adelie  Torgersen          42.100         19.100            195.000    4,000.000    Male
# 80      Adelie  Torgersen          34.600         17.200            189.000    3,200.000  Female
# 81      Adelie  Torgersen          42.900         17.600            196.000    4,700.000    Male
# 82      Adelie  Torgersen          36.700         18.800            187.000    3,800.000  Female
# 83      Adelie  Torgersen          35.100         19.400            193.000    4,200.000    Male
# 84      Adelie      Dream          37.300         17.800            191.000    3,350.000  Female
# 85      Adelie      Dream          41.300         20.300            194.000    3,550.000    Male
# 86      Adelie      Dream          36.300         19.500            190.000    3,800.000    Male
# 87      Adelie      Dream          36.900         18.600            189.000    3,500.000  Female
# 88      Adelie      Dream          38.300         19.200            189.000    3,950.000    Male
# 89      Adelie      Dream          38.900         18.800            190.000    3,600.000  Female
# 90      Adelie      Dream          35.700         18.000            202.000    3,550.000  Female
# 91      Adelie      Dream          41.100         18.100            205.000    4,300.000    Male
# 92      Adelie      Dream          34.000         17.100            185.000    3,400.000  Female
# 93      Adelie      Dream          39.600         18.100            186.000    4,450.000    Male
# 94      Adelie      Dream          36.200         17.300            187.000    3,300.000  Female
# 95      Adelie      Dream          40.800         18.900            208.000    4,300.000    Male
# 96      Adelie      Dream          38.100         18.600            190.000    3,700.000  Female
# 97      Adelie      Dream          40.300         18.500            196.000    4,350.000    Male
# 98      Adelie      Dream          33.100         16.100            178.000    2,900.000  Female
# 99      Adelie      Dream          43.200         18.500            192.000    4,100.000    Male
# 100     Adelie     Biscoe          35.000         17.900            192.000    3,725.000  Female
# 101     Adelie     Biscoe          41.000         20.000            203.000    4,725.000    Male
# 102     Adelie     Biscoe          37.700         16.000            183.000    3,075.000  Female
# 103     Adelie     Biscoe          37.800         20.000            190.000    4,250.000    Male
# 104     Adelie     Biscoe          37.900         18.600            193.000    2,925.000  Female
# 105     Adelie     Biscoe          39.700         18.900            184.000    3,550.000    Male
# 106     Adelie     Biscoe          38.600         17.200            199.000    3,750.000  Female
# 107     Adelie     Biscoe          38.200         20.000            190.000    3,900.000    Male
# 108     Adelie     Biscoe          38.100         17.000            181.000    3,175.000  Female
# 109     Adelie     Biscoe          43.200         19.000            197.000    4,775.000    Male
# 110     Adelie     Biscoe          38.100         16.500            198.000    3,825.000  Female
# 111     Adelie     Biscoe          45.600         20.300            191.000    4,600.000    Male
# 112     Adelie     Biscoe          39.700         17.700            193.000    3,200.000  Female
# 113     Adelie     Biscoe          42.200         19.500            197.000    4,275.000    Male
# 114     Adelie     Biscoe          39.600         20.700            191.000    3,900.000  Female
# 115     Adelie     Biscoe          42.700         18.300            196.000    4,075.000    Male
# 116     Adelie  Torgersen          38.600         17.000            188.000    2,900.000  Female
# 117     Adelie  Torgersen          37.300         20.500            199.000    3,775.000    Male
# 118     Adelie  Torgersen          35.700         17.000            189.000    3,350.000  Female
# 119     Adelie  Torgersen          41.100         18.600            189.000    3,325.000    Male
# 120     Adelie  Torgersen          36.200         17.200            187.000    3,150.000  Female
# 121     Adelie  Torgersen          37.700         19.800            198.000    3,500.000    Male
# 122     Adelie  Torgersen          40.200         17.000            176.000    3,450.000  Female
# 123     Adelie  Torgersen          41.400         18.500            202.000    3,875.000    Male
# 124     Adelie  Torgersen          35.200         15.900            186.000    3,050.000  Female
# 125     Adelie  Torgersen          40.600         19.000            199.000    4,000.000    Male
# 126     Adelie  Torgersen          38.800         17.600            191.000    3,275.000  Female
# 127     Adelie  Torgersen          41.500         18.300            195.000    4,300.000    Male
# 128     Adelie  Torgersen          39.000         17.100            191.000    3,050.000  Female
# 129     Adelie  Torgersen          44.100         18.000            210.000    4,000.000    Male
# 130     Adelie  Torgersen          38.500         17.900            190.000    3,325.000  Female
# 131     Adelie  Torgersen          43.100         19.200            197.000    3,500.000    Male
# 132     Adelie      Dream          36.800         18.500            193.000    3,500.000  Female
# 133     Adelie      Dream          37.500         18.500            199.000    4,475.000    Male
# 134     Adelie      Dream          38.100         17.600            187.000    3,425.000  Female
# 135     Adelie      Dream          41.100         17.500            190.000    3,900.000    Male
# 136     Adelie      Dream          35.600         17.500            191.000    3,175.000  Female
# 137     Adelie      Dream          40.200         20.100            200.000    3,975.000    Male
# 138     Adelie      Dream          37.000         16.500            185.000    3,400.000  Female
# 139     Adelie      Dream          39.700         17.900            193.000    4,250.000    Male
# 140     Adelie      Dream          40.200         17.100            193.000    3,400.000  Female
# 141     Adelie      Dream          40.600         17.200            187.000    3,475.000    Male
# 142     Adelie      Dream          32.100         15.500            188.000    3,050.000  Female
# 143     Adelie      Dream          40.700         17.000            190.000    3,725.000    Male
# 144     Adelie      Dream          37.300         16.800            192.000    3,000.000  Female
# 145     Adelie      Dream          39.000         18.700            185.000    3,650.000    Male
# 146     Adelie      Dream          39.200         18.600            190.000    4,250.000    Male
# 147     Adelie      Dream          36.600         18.400            184.000    3,475.000  Female
# 148     Adelie      Dream          36.000         17.800            195.000    3,450.000  Female
# 149     Adelie      Dream          37.800         18.100            193.000    3,750.000    Male
# 150     Adelie      Dream          36.000         17.100            187.000    3,700.000  Female
# 151     Adelie      Dream          41.500         18.500            201.000    4,000.000    Male
# 152  Chinstrap      Dream          46.500         17.900            192.000    3,500.000  Female
# 153  Chinstrap      Dream          50.000         19.500            196.000    3,900.000    Male
# 154  Chinstrap      Dream          51.300         19.200            193.000    3,650.000    Male
# 155  Chinstrap      Dream          45.400         18.700            188.000    3,525.000  Female
# 156  Chinstrap      Dream          52.700         19.800            197.000    3,725.000    Male
# 157  Chinstrap      Dream          45.200         17.800            198.000    3,950.000  Female
# 158  Chinstrap      Dream          46.100         18.200            178.000    3,250.000  Female
# 159  Chinstrap      Dream          51.300         18.200            197.000    3,750.000    Male
# 160  Chinstrap      Dream          46.000         18.900            195.000    4,150.000  Female
# 161  Chinstrap      Dream          51.300         19.900            198.000    3,700.000    Male
# 162  Chinstrap      Dream          46.600         17.800            193.000    3,800.000  Female
# 163  Chinstrap      Dream          51.700         20.300            194.000    3,775.000    Male
# 164  Chinstrap      Dream          47.000         17.300            185.000    3,700.000  Female
# 165  Chinstrap      Dream          52.000         18.100            201.000    4,050.000    Male
# 166  Chinstrap      Dream          45.900         17.100            190.000    3,575.000  Female
# 167  Chinstrap      Dream          50.500         19.600            201.000    4,050.000    Male
# 168  Chinstrap      Dream          50.300         20.000            197.000    3,300.000    Male
# 169  Chinstrap      Dream          58.000         17.800            181.000    3,700.000  Female
# 170  Chinstrap      Dream          46.400         18.600            190.000    3,450.000  Female
# 171  Chinstrap      Dream          49.200         18.200            195.000    4,400.000    Male
# 172  Chinstrap      Dream          42.400         17.300            181.000    3,600.000  Female
# 173  Chinstrap      Dream          48.500         17.500            191.000    3,400.000    Male
# 174  Chinstrap      Dream          43.200         16.600            187.000    2,900.000  Female
# 175  Chinstrap      Dream          50.600         19.400            193.000    3,800.000    Male
# 176  Chinstrap      Dream          46.700         17.900            195.000    3,300.000  Female
# 177  Chinstrap      Dream          52.000         19.000            197.000    4,150.000    Male
# 178  Chinstrap      Dream          50.500         18.400            200.000    3,400.000  Female
# 179  Chinstrap      Dream          49.500         19.000            200.000    3,800.000    Male
# 180  Chinstrap      Dream          46.400         17.800            191.000    3,700.000  Female
# 181  Chinstrap      Dream          52.800         20.000            205.000    4,550.000    Male
# 182  Chinstrap      Dream          40.900         16.600            187.000    3,200.000  Female
# 183  Chinstrap      Dream          54.200         20.800            201.000    4,300.000    Male
# 184  Chinstrap      Dream          42.500         16.700            187.000    3,350.000  Female
# 185  Chinstrap      Dream          51.000         18.800            203.000    4,100.000    Male
# 186  Chinstrap      Dream          49.700         18.600            195.000    3,600.000    Male
# 187  Chinstrap      Dream          47.500         16.800            199.000    3,900.000  Female
# 188  Chinstrap      Dream          47.600         18.300            195.000    3,850.000  Female
# 189  Chinstrap      Dream          52.000         20.700            210.000    4,800.000    Male
# 190  Chinstrap      Dream          46.900         16.600            192.000    2,700.000  Female
# 191  Chinstrap      Dream          53.500         19.900            205.000    4,500.000    Male
# 192  Chinstrap      Dream          49.000         19.500            210.000    3,950.000    Male
# 193  Chinstrap      Dream          46.200         17.500            187.000    3,650.000  Female
# 194  Chinstrap      Dream          50.900         19.100            196.000    3,550.000    Male
# 195  Chinstrap      Dream          45.500         17.000            196.000    3,500.000  Female
# 196  Chinstrap      Dream          50.900         17.900            196.000    3,675.000  Female
# 197  Chinstrap      Dream          50.800         18.500            201.000    4,450.000    Male
# 198  Chinstrap      Dream          50.100         17.900            190.000    3,400.000  Female
# 199  Chinstrap      Dream          49.000         19.600            212.000    4,300.000    Male
# 200  Chinstrap      Dream          51.500         18.700            187.000    3,250.000    Male
# 201  Chinstrap      Dream          49.800         17.300            198.000    3,675.000  Female
# 202  Chinstrap      Dream          48.100         16.400            199.000    3,325.000  Female
# 203  Chinstrap      Dream          51.400         19.000            201.000    3,950.000    Male
# 204  Chinstrap      Dream          45.700         17.300            193.000    3,600.000  Female
# 205  Chinstrap      Dream          50.700         19.700            203.000    4,050.000    Male
# 206  Chinstrap      Dream          42.500         17.300            187.000    3,350.000  Female
# 207  Chinstrap      Dream          52.200         18.800            197.000    3,450.000    Male
# 208  Chinstrap      Dream          45.200         16.600            191.000    3,250.000  Female
# 209  Chinstrap      Dream          49.300         19.900            203.000    4,050.000    Male
# 210  Chinstrap      Dream          50.200         18.800            202.000    3,800.000    Male
# 211  Chinstrap      Dream          45.600         19.400            194.000    3,525.000  Female
# 212  Chinstrap      Dream          51.900         19.500            206.000    3,950.000    Male
# 213  Chinstrap      Dream          46.800         16.500            189.000    3,650.000  Female
# 214  Chinstrap      Dream          45.700         17.000            195.000    3,650.000  Female
# 215  Chinstrap      Dream          55.800         19.800            207.000    4,000.000    Male
# 216  Chinstrap      Dream          43.500         18.100            202.000    3,400.000  Female
# 217  Chinstrap      Dream          49.600         18.200            193.000    3,775.000    Male
# 218  Chinstrap      Dream          50.800         19.000            210.000    4,100.000    Male
# 219  Chinstrap      Dream          50.200         18.700            198.000    3,775.000  Female
# 220     Gentoo     Biscoe          46.100         13.200            211.000    4,500.000  Female
# 221     Gentoo     Biscoe          50.000         16.300            230.000    5,700.000    Male
# 222     Gentoo     Biscoe          48.700         14.100            210.000    4,450.000  Female
# 223     Gentoo     Biscoe          50.000         15.200            218.000    5,700.000    Male
# 224     Gentoo     Biscoe          47.600         14.500            215.000    5,400.000    Male
# 225     Gentoo     Biscoe          46.500         13.500            210.000    4,550.000  Female
# 226     Gentoo     Biscoe          45.400         14.600            211.000    4,800.000  Female
# 227     Gentoo     Biscoe          46.700         15.300            219.000    5,200.000    Male
# 228     Gentoo     Biscoe          43.300         13.400            209.000    4,400.000  Female
# 229     Gentoo     Biscoe          46.800         15.400            215.000    5,150.000    Male
# 230     Gentoo     Biscoe          40.900         13.700            214.000    4,650.000  Female
# 231     Gentoo     Biscoe          49.000         16.100            216.000    5,550.000    Male
# 232     Gentoo     Biscoe          45.500         13.700            214.000    4,650.000  Female
# 233     Gentoo     Biscoe          48.400         14.600            213.000    5,850.000    Male
# 234     Gentoo     Biscoe          45.800         14.600            210.000    4,200.000  Female
# 235     Gentoo     Biscoe          49.300         15.700            217.000    5,850.000    Male
# 236     Gentoo     Biscoe          42.000         13.500            210.000    4,150.000  Female
# 237     Gentoo     Biscoe          49.200         15.200            221.000    6,300.000    Male
# 238     Gentoo     Biscoe          46.200         14.500            209.000    4,800.000  Female
# 239     Gentoo     Biscoe          48.700         15.100            222.000    5,350.000    Male
# 240     Gentoo     Biscoe          50.200         14.300            218.000    5,700.000    Male
# 241     Gentoo     Biscoe          45.100         14.500            215.000    5,000.000  Female
# 242     Gentoo     Biscoe          46.500         14.500            213.000    4,400.000  Female
# 243     Gentoo     Biscoe          46.300         15.800            215.000    5,050.000    Male
# 244     Gentoo     Biscoe          42.900         13.100            215.000    5,000.000  Female
# 245     Gentoo     Biscoe          46.100         15.100            215.000    5,100.000    Male
# 246     Gentoo     Biscoe          44.500         14.300            216.000    4,100.000     NaN
# 247     Gentoo     Biscoe          47.800         15.000            215.000    5,650.000    Male
# 248     Gentoo     Biscoe          48.200         14.300            210.000    4,600.000  Female
# 249     Gentoo     Biscoe          50.000         15.300            220.000    5,550.000    Male
# 250     Gentoo     Biscoe          47.300         15.300            222.000    5,250.000    Male
# 251     Gentoo     Biscoe          42.800         14.200            209.000    4,700.000  Female
# 252     Gentoo     Biscoe          45.100         14.500            207.000    5,050.000  Female
# 253     Gentoo     Biscoe          59.600         17.000            230.000    6,050.000    Male
# 254     Gentoo     Biscoe          49.100         14.800            220.000    5,150.000  Female
# 255     Gentoo     Biscoe          48.400         16.300            220.000    5,400.000    Male
# 256     Gentoo     Biscoe          42.600         13.700            213.000    4,950.000  Female
# 257     Gentoo     Biscoe          44.400         17.300            219.000    5,250.000    Male
# 258     Gentoo     Biscoe          44.000         13.600            208.000    4,350.000  Female
# 259     Gentoo     Biscoe          48.700         15.700            208.000    5,350.000    Male
# 260     Gentoo     Biscoe          42.700         13.700            208.000    3,950.000  Female
# 261     Gentoo     Biscoe          49.600         16.000            225.000    5,700.000    Male
# 262     Gentoo     Biscoe          45.300         13.700            210.000    4,300.000  Female
# 263     Gentoo     Biscoe          49.600         15.000            216.000    4,750.000    Male
# 264     Gentoo     Biscoe          50.500         15.900            222.000    5,550.000    Male
# 265     Gentoo     Biscoe          43.600         13.900            217.000    4,900.000  Female
# 266     Gentoo     Biscoe          45.500         13.900            210.000    4,200.000  Female
# 267     Gentoo     Biscoe          50.500         15.900            225.000    5,400.000    Male
# 268     Gentoo     Biscoe          44.900         13.300            213.000    5,100.000  Female
# 269     Gentoo     Biscoe          45.200         15.800            215.000    5,300.000    Male
# 270     Gentoo     Biscoe          46.600         14.200            210.000    4,850.000  Female
# 271     Gentoo     Biscoe          48.500         14.100            220.000    5,300.000    Male
# 272     Gentoo     Biscoe          45.100         14.400            210.000    4,400.000  Female
# 273     Gentoo     Biscoe          50.100         15.000            225.000    5,000.000    Male
# 274     Gentoo     Biscoe          46.500         14.400            217.000    4,900.000  Female
# 275     Gentoo     Biscoe          45.000         15.400            220.000    5,050.000    Male
# 276     Gentoo     Biscoe          43.800         13.900            208.000    4,300.000  Female
# 277     Gentoo     Biscoe          45.500         15.000            220.000    5,000.000    Male
# 278     Gentoo     Biscoe          43.200         14.500            208.000    4,450.000  Female
# 279     Gentoo     Biscoe          50.400         15.300            224.000    5,550.000    Male
# 280     Gentoo     Biscoe          45.300         13.800            208.000    4,200.000  Female
# 281     Gentoo     Biscoe          46.200         14.900            221.000    5,300.000    Male
# 282     Gentoo     Biscoe          45.700         13.900            214.000    4,400.000  Female
# 283     Gentoo     Biscoe          54.300         15.700            231.000    5,650.000    Male
# 284     Gentoo     Biscoe          45.800         14.200            219.000    4,700.000  Female
# 285     Gentoo     Biscoe          49.800         16.800            230.000    5,700.000    Male
# 286     Gentoo     Biscoe          46.200         14.400            214.000    4,650.000     NaN
# 287     Gentoo     Biscoe          49.500         16.200            229.000    5,800.000    Male
# 288     Gentoo     Biscoe          43.500         14.200            220.000    4,700.000  Female
# 289     Gentoo     Biscoe          50.700         15.000            223.000    5,550.000    Male
# 290     Gentoo     Biscoe          47.700         15.000            216.000    4,750.000  Female
# 291     Gentoo     Biscoe          46.400         15.600            221.000    5,000.000    Male
# 292     Gentoo     Biscoe          48.200         15.600            221.000    5,100.000    Male
# 293     Gentoo     Biscoe          46.500         14.800            217.000    5,200.000  Female
# 294     Gentoo     Biscoe          46.400         15.000            216.000    4,700.000  Female
# 295     Gentoo     Biscoe          48.600         16.000            230.000    5,800.000    Male
# 296     Gentoo     Biscoe          47.500         14.200            209.000    4,600.000  Female
# 297     Gentoo     Biscoe          51.100         16.300            220.000    6,000.000    Male
# 298     Gentoo     Biscoe          45.200         13.800            215.000    4,750.000  Female
# 299     Gentoo     Biscoe          45.200         16.400            223.000    5,950.000    Male
# 300     Gentoo     Biscoe          49.100         14.500            212.000    4,625.000  Female
# 301     Gentoo     Biscoe          52.500         15.600            221.000    5,450.000    Male
# 302     Gentoo     Biscoe          47.400         14.600            212.000    4,725.000  Female
# 303     Gentoo     Biscoe          50.000         15.900            224.000    5,350.000    Male
# 304     Gentoo     Biscoe          44.900         13.800            212.000    4,750.000  Female
# 305     Gentoo     Biscoe          50.800         17.300            228.000    5,600.000    Male
# 306     Gentoo     Biscoe          43.400         14.400            218.000    4,600.000  Female
# 307     Gentoo     Biscoe          51.300         14.200            218.000    5,300.000    Male
# 308     Gentoo     Biscoe          47.500         14.000            212.000    4,875.000  Female
# 309     Gentoo     Biscoe          52.100         17.000            230.000    5,550.000    Male
# 310     Gentoo     Biscoe          47.500         15.000            218.000    4,950.000  Female
# 311     Gentoo     Biscoe          52.200         17.100            228.000    5,400.000    Male
# 312     Gentoo     Biscoe          45.500         14.500            212.000    4,750.000  Female
# 313     Gentoo     Biscoe          49.500         16.100            224.000    5,650.000    Male
# 314     Gentoo     Biscoe          44.500         14.700            214.000    4,850.000  Female
# 315     Gentoo     Biscoe          50.800         15.700            226.000    5,200.000    Male
# 316     Gentoo     Biscoe          49.400         15.800            216.000    4,925.000    Male
# 317     Gentoo     Biscoe          46.900         14.600            222.000    4,875.000  Female
# 318     Gentoo     Biscoe          48.400         14.400            203.000    4,625.000  Female
# 319     Gentoo     Biscoe          51.100         16.500            225.000    5,250.000    Male
# 320     Gentoo     Biscoe          48.500         15.000            219.000    4,850.000  Female
# 321     Gentoo     Biscoe          55.900         17.000            228.000    5,600.000    Male
# 322     Gentoo     Biscoe          47.200         15.500            215.000    4,975.000  Female
# 323     Gentoo     Biscoe          49.100         15.000            228.000    5,500.000    Male
# 324     Gentoo     Biscoe          47.300         13.800            216.000    4,725.000     NaN
# 325     Gentoo     Biscoe          46.800         16.100            215.000    5,500.000    Male
# 326     Gentoo     Biscoe          41.700         14.700            210.000    4,700.000  Female
# 327     Gentoo     Biscoe          53.400         15.800            219.000    5,500.000    Male
# 328     Gentoo     Biscoe          43.300         14.000            208.000    4,575.000  Female
# 329     Gentoo     Biscoe          48.100         15.100            209.000    5,500.000    Male
# 330     Gentoo     Biscoe          50.500         15.200            216.000    5,000.000  Female
# 331     Gentoo     Biscoe          49.800         15.900            229.000    5,950.000    Male
# 332     Gentoo     Biscoe          43.500         15.200            213.000    4,650.000  Female
# 333     Gentoo     Biscoe          51.500         16.300            230.000    5,500.000    Male
# 334     Gentoo     Biscoe          46.200         14.100            217.000    4,375.000  Female
# 335     Gentoo     Biscoe          55.100         16.000            230.000    5,850.000    Male
# 336     Gentoo     Biscoe          44.500         15.700            217.000    4,875.000     NaN
# 337     Gentoo     Biscoe          48.800         16.200            222.000    6,000.000    Male
# 338     Gentoo     Biscoe          47.200         13.700            214.000    4,925.000  Female
# 339     Gentoo     Biscoe             nan            nan                nan          nan     NaN
# 340     Gentoo     Biscoe          46.800         14.300            215.000    4,850.000  Female
# 341     Gentoo     Biscoe          50.400         15.700            222.000    5,750.000    Male
# 342     Gentoo     Biscoe          45.200         14.800            212.000    5,200.000  Female
# 343     Gentoo     Biscoe          49.900         16.100            213.000    5,400.000    Male

# %% [markdown]
# ## Axes level functions (e.g. `histplot`, `scatterplot`)

# %%
sns.histplot(data=penguins, x='flipper_length_mm', hue='species', multiple='stack')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.kdeplot(data=penguins, x='flipper_length_mm', hue='species', multiple='stack', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.kdeplot(data=penguins, x='flipper_length_mm', hue='species', multiple='layer', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.kdeplot(data=penguins, x='flipper_length_mm', hue='species', multiple='fill', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Density'>

# %% [markdown]
# ## Figure level functions (`displot`, `relplot`, `catplot`)

# %%
sns.displot(data=penguins, x='flipper_length_mm', hue='species', multiple='stack')

# %%
sns.displot(data=penguins, x='flipper_length_mm', hue='species', multiple='stack', kind='kde', alpha=0.5)

# %% [markdown]
# ## Faceting with figure level functions

# %%
sns.displot(data=penguins, x='flipper_length_mm', hue='species', col='species')

# %% [markdown]
# ## Axes level functioins make self contained plots

# %%
f, axs = plt.subplots(1, 2, figsize=(8,4), gridspec_kw=dict(width_ratios=[4, 3]))
sns.scatterplot(data=penguins, x='flipper_length_mm', y='bill_length_mm', hue='species', ax=axs[0])
sns.histplot(data=penguins, x='species', hue='species', shrink=0.8, alpha=0.8, legend=False, ax=axs[1])
# Out:
# <AxesSubplot:xlabel='species', ylabel='Count'>

# %%
f, axs = plt.subplots(1, 2, figsize=(8,4), gridspec_kw=dict(width_ratios=[4, 3]))
sns.scatterplot(data=penguins, x='flipper_length_mm', y='bill_length_mm', hue='species', ax=axs[0])
sns.histplot(data=penguins, x='species', hue='species', shrink=0.8, alpha=0.8, legend=False, ax=axs[1])
f.tight_layout()

# %% [markdown]
# ## Figure level functions own the figure

# %%
tips = sns.load_dataset('tips')
g = sns.relplot(data=tips, x='total_bill', y='tip')
g.ax.axline(xy1=(10, 2), slope=0.2, color='r', dashes=(5, 2))

# %% [markdown]
# ## Customize plot from a figure level function

# %%
g = sns.relplot(data=penguins, x='flipper_length_mm', y='bill_length_mm', col='sex')
g.set_axis_labels('Flipper length (mm)', 'Bill length (mm)')

# %% [markdown]
# ## Specify figure size

# %% [markdown]
# * Axes level functions
#     * size determined by axes layout of the figure
# * Figure level functions
#     * matplotlib: set `figsize` in `plt.subplots` or `mpl.Figure.set_size_inches()`
#     * seaborn: `height`, `aspect` parameters (width = height * aspect)
#         * Parameters correspond to size of each subplot

# %% [markdown]
# Matplotlib

# %%
f, ax = plt.subplots()

# %%
f, ax = plt.subplots(1, 2, sharey=True)

# %% [markdown]
# Seaborn FacetGrid

# %%
g = sns.FacetGrid(penguins)

# %%
g = sns.FacetGrid(penguins, col='sex')

# %%
g = sns.FacetGrid(penguins, col='sex', height=3.5, aspect=1.2)

# %% [markdown]
# ## Combine multiple views on the data

# %% [markdown]
# `jointplot` and `pairplot`

# %%
sns.jointplot(data=penguins, x='flipper_length_mm', y='bill_length_mm', hue='species')

# %%
sns.pairplot(data=penguins, hue='species')

# %%
sns.jointplot(data=penguins, x='flipper_length_mm', y='bill_length_mm', hue='species', kind='hist')

# %% [markdown]
# # Data structures accepted by Seaborn

# %% [markdown]
# https://seaborn.pydata.org/tutorial/data_structure.html

# %% [markdown]
# ## Clean up messy data

# %%
anagrams = sns.load_dataset('anagrams')
anagrams
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2 4.000     7
# 1        2  divided     3 4.000     5
# 2        3  divided     3 5.000     6
# 3        4  divided     5 7.000     5
# 4        5  divided     4 5.000     8
# 5        6  divided     5 5.000     6
# 6        7  divided     5 4.500     6
# 7        8  divided     5 7.000     8
# 8        9  divided     2 3.000     7
# 9       10  divided     6 5.000     6
# 10      11  focused     6 5.000     6
# 11      12  focused     8 9.000     8
# 12      13  focused     6 5.000     9
# 13      14  focused     8 8.000     7
# 14      15  focused     8 8.000     7
# 15      16  focused     6 8.000     7
# 16      17  focused     7 7.000     6
# 17      18  focused     7 8.000     6
# 18      19  focused     5 6.000     6
# 19      20  focused     6 6.000     5

# %%
anagrams_long = anagrams.melt(id_vars=['subidr', 'attnr'], var_name='solutions', value_name='score')
anagrams_long.head()
# Out:
#    subidr    attnr solutions  score
# 0       1  divided      num1  2.000
# 1       2  divided      num1  3.000
# 2       3  divided      num1  3.000
# 3       4  divided      num1  5.000
# 4       5  divided      num1  4.000

# %% [markdown]
# Plot the average score as a function of attention and number of solutions

# %%
sns.catplot(data=anagrams_long, x='solutions', y='score', hue='attnr', kind='point')

# %% [markdown]
# ## Options for visualizing long form data

# %%
flights = sns.load_dataset('flights')
flights_dict = flights.to_dict()
sns.relplot(data=flights_dict, x="year", y="passengers", hue="month", kind="line")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
type(flights_dict['year'])
# Out:
# dict

# %%
flights_avg = flights.groupby('year').mean()
flights_avg
# Out:
#       passengers
# year
# 1949     126.667
# 1950     139.667
# 1951     170.167
# 1952     197.000
# 1953     225.000
# 1954     238.917
# 1955     284.000
# 1956     328.250
# 1957     368.417
# 1958     381.000
# 1959     428.333
# 1960     476.167

# %%
sns.relplot(data=flights_avg, x='year', y='passengers', kind='line')

# %% [markdown]
# Or, pass vectors

# %%
year = flights_avg.index
passengers = flights_avg['passengers']
sns.relplot(x=year, y=passengers, kind='line')

# %% [markdown]
# ### Collections with different length

# %%
flights_wide = flights.pivot(index="year", columns="month", values="passengers")

two_series = [flights_wide.loc[:1955, 'Jan'], flights_wide.loc[1952:, 'Aug']]
sns.relplot(data=two_series, kind='line')

# %% [markdown]
# ### remove index info

# %%
two_series = [s.to_numpy() for s in two_series]
sns.relplot(data=two_series, kind='line')

# %% [markdown]
# # Visualizing statistical relationships

# %% [markdown]
# https://seaborn.pydata.org/tutorial/relational.html

# %% [markdown]
# `relplot` (figure level)
#
# * `scatterplot()` (with `kind='scatter'`)
# * `lineplot()` (with `kind='line'`)

# %% [markdown]
# ## Relate variables with scatter plots

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
tips = sns.load_dataset('tips')
sns.relplot(x='total_bill', y='tip', data=tips)

# %% [markdown]
# ### Add a 3rd dimension using `hue` (change colors of points)

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker')

# %% [markdown]
# ### Different marker style for each class

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker', style='smoker')

# %% [markdown]
# ### 4D using hue and style

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker', style='time')

# %% [markdown]
# ### If hue is a numeric value, uses a sequential palette

# %%
sns.relplot(x="total_bill", y="tip", hue="size", data=tips);

# %% [markdown]
# ### Customize palette

# %%
sns.relplot(x="total_bill", y="tip", hue="size", data=tips, palette="ch:r=-0.5, l=0.75");

# %% [markdown]
# ### Change size of points

# %%
sns.relplot(x="total_bill", y="tip", size="size", data=tips);

# %%
sns.relplot(x="total_bill", y="tip", size="size", sizes=(15,200), data=tips, alpha=0.7);

# %% [markdown]
# ## Emphasize continuity with line plots

# %% [markdown]
# by default, the data is sorted by `x` before plotting with `lineplot`

# %%
df = pd.DataFrame(dict(time=np.arange(500),
                       value=np.random.randn(500).cumsum()))
g = sns.relplot(x="time", y="value", kind="line", data=df)
g.fig.autofmt_xdate()

# %% [markdown]
# #### Aggregation and representing uncertainty

# %%
fmri = sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region  signal
# 0        s13         18  stim  parietal  -0.018
# 1         s5         14  stim  parietal  -0.081
# 2        s12         18  stim  parietal  -0.081
# 3        s11         18  stim  parietal  -0.046
# 4        s10         18  stim  parietal  -0.038
# ...      ...        ...   ...       ...     ...
# 1059      s0          8   cue   frontal   0.018
# 1060     s13          7   cue   frontal  -0.029
# 1061     s12          7   cue   frontal  -0.005
# 1062     s11          7   cue   frontal  -0.025
# 1063      s0          0   cue  parietal  -0.007

# %% [markdown]
# Confidence intervals are computed using bootstrapping.
#
# May be time-intensive for larger datasets

# %%
sns.relplot(x='timepoint', y='signal', kind='line', data=fmri)

# %%
fmri.query("timepoint == 5").agg(['mean', 'std'])
# Out:
#       timepoint  signal
# mean      5.000   0.138
# std       0.000   0.123

# %% [markdown]
# #### No confidence interval
#
# plots the mean of each point

# %%
sns.relplot(x='timepoint', y='signal', ci=None, kind='line', data=fmri)

# %% [markdown]
# #### Show standard deviation

# %%
sns.relplot(x='timepoint', y='signal', ci='sd', kind='line', data=fmri)

# %% [markdown]
# #### Turn off aggregation

# %%
sns.relplot(x='timepoint', y='signal', estimator=None, kind='line', data=fmri)

# %% [markdown]
# ## Plotting subsets of data with semantic mappings

# %%
sns.relplot(x='timepoint', y='signal', hue='event', kind='line', data=fmri)

# %%
sns.relplot(x='timepoint', y='signal', hue='region', style='event', kind='line', data=fmri)

# %%
sns.relplot(x='timepoint', y='signal', hue='region', style='event', kind='line', markers=True, dashes=False, data=fmri)

# %% [markdown]
# ## Plotting with date data

# %%
df = pd.DataFrame(dict(time=pd.date_range("2021-01-01", periods=500),
                       value=np.random.randn(500).cumsum()))
g = sns.relplot(x="time", y="value", kind="line", data=df)
g.fig.autofmt_xdate()
g.ax.grid(False)

# %% [markdown]
# ## Show multiple relationships with facets (`col` variable)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', col='time', data=tips)

# %%
sns.relplot(x="timepoint", y="signal", hue="subject",
            col="region", row="event", height=3,
            kind="line", estimator=None, data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="event", style="event",
            col="subject", col_wrap=5,
            height=3, aspect=.75, linewidth=2.5,
            kind="line", data=fmri.query("region == 'frontal'"));

# %% [markdown]
# # Visualizing distributions of data

# %% [markdown]
# The distributions module contains several functions designed to answer questions such as these. The axes-level functions are `histplot()`, `kdeplot()`, `ecdfplot()`, and `rugplot()`. They are grouped together within the figure-level `displot()`, `jointplot()`, and `pairplot()` functions.

# %% [markdown]
# ## Plot univariate histograms

# %%
penguins = sns.load_dataset('penguins')
sns.displot(penguins, x='flipper_length_mm');

# %%
sns.displot(penguins, x='flipper_length_mm', binwidth=3);

# %%
sns.displot(penguins, x='flipper_length_mm', bins=25);

# %%
tips = sns.load_dataset('tips')
sns.displot(tips, x='size')

# %% [markdown]
# ### specify the precise bin breaks by passing an array to bins

# %%
sns.displot(tips, x="size", bins=[1, 2, 3, 4, 5, 6, 7])

# %% [markdown]
# ### setting discrete=True, which chooses bin breaks that represent the unique values in a dataset with bars that are centered on their corresponding value

# %%
sns.displot(tips, x="size", discrete=True, shrink=0.8, alpha=0.5)

# %%
sns.displot(penguins, x="flipper_length_mm", col='sex', )

# %% [markdown]
# ## `FacetGrid.map`

# %%
with sns.axes_style("white"):
    g = sns.FacetGrid(tips, row="sex", col="smoker", margin_titles=True, height=2.5)
g.map(sns.scatterplot, "total_bill", "tip", color="#334488")
g.set_axis_labels("Total bill (US Dollars)", "Tip")
g.set(xticks=[10, 30, 50], yticks=[2, 6, 10])
g.fig.subplots_adjust(wspace=.02, hspace=.02)

# %%
g = sns.FacetGrid(tips, col="smoker", margin_titles=True, height=4)
g.map(plt.scatter, "total_bill", "tip", color="#338844", edgecolor="white", s=50, lw=1)
for ax in g.axes.flat:
    ax.axline((0, 0), slope=.2, c=".2", ls="--", zorder=0)
g.set(xlim=(0, 60), ylim=(0, 14))

# %% [markdown]
# ### Custom function to map to `FacetGrid`

# %%
from scipy import stats
def quantile_plot(x, **kwargs):
    quantiles, xr = stats.probplot(x, fit=False)
    plt.scatter(xr, quantiles, **kwargs)

g = sns.FacetGrid(tips, col="sex", height=4)
g.map(quantile_plot, "total_bill")
